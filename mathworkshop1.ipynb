# %% [markdown]
# <a href="https://colab.research.google.com/github/kripakunwar007-ship-it/math-workshop/blob/main/mathworkshop1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fib (n):
  a=0
  b=1
  for i in range(n):
    print(a)
    f=a+b
    a=b
    b=f
n= int(input("Enter the number of terms: "))
fib(n)

# %%
def myPow(x, n):
  i=1
  result= x
  while i<n:
    result *= x
    i+=1
  return result
myPow(5,3)

# %%
def sumDigits(n):
    r = n
    sum = 0
    while r != 0:
        q = r // 10
        digit = r % 10
        sum += digit
        r = q
    return sum

print(sumDigits(234))

# %%
def squaredSum(n):
  sum = 0
  for i in n:
    sum += i * i
  print(sum)
squaredSum([2,3,4])

# %%
def sumDigits(num):
  sum = 0
  for i in range(num+1):
    sum+=i
  return sum
sumDigits(6)
